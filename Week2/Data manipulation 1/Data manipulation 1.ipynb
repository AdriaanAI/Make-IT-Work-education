# %% [markdown]
# # Pandas: Inspecteren & basishandelingen
# - Voer onderstaande cel uit om het sales dataframe aan te maken.

# %%
import pandas as pd

sales = pd.read_csv('sales data-set.csv')

# %% [markdown]
# ## 1 Inspecteren
# - Toon de eerste 5 rijen van sales.

# %%
display(sales.head(5))
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %% [markdown]
# - Verander de 'Date' kolom in de internationale standaard voor datum en tijd.
# - Toon de eerste 5 rijen opnieuw.

# %%
sales['Date'] = pd.to_datetime(sales['Date'],dayfirst=True)
display(sales.head(5))
display(sales.iloc[0:5,3:5])
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Year
# 0      1     1 2010-02-05      24924.50      False  2010
# 1      1     1 2010-02-12      46039.49       True  2010
# 2      1     1 2010-02-19      41595.55      False  2010
# 3      1     1 2010-02-26      19403.54      False  2010
# 4      1     1 2010-03-05      21827.90      False  2010
#    Weekly_Sales  IsHoliday
# 0      24924.50      False
# 1      46039.49       True
# 2      41595.55      False
# 3      19403.54      False
# 4      21827.90      False

# %% [markdown]
# - Toon informatie over het datatype van iedere kolom.
# - Zijn er kolommen die 'lege-waardes' bevatten?

# %%
display (sales.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2)
# memory usage: 13.3 MB
# None

# %% [markdown]
# - Toon het aantal rijen en kolommen.

# %%
display (sales.shape)
# Out:
# (421570, 5)

# %% [markdown]
# - Toon een overzicht waarin de basisstatistieken van het dataframe worden getoond.
# - Wat valt je op aan het minimum van 'Weekly_Sales'? Hoe kan dit zijn ontstaan?
# - Wat is de hoogste omzet volgens dit overzicht?
# - Leg aan de hand van dit overzicht uit wat 25%, 50% en 75% betekenen.

# %%
display (sales.describe())

print('\nMinimum "Weekly Sales" is negative.')
print('\Hoogste omzet is 693099.360000')

import seaborn as sns
sns.boxplot(x=sales['Weekly_Sales'], showfliers = False )
# Out:
#                Store           Dept   Weekly_Sales           Year
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123    2010.968591
# std        12.785297      30.492054   22711.183519       0.796876
# min         1.000000       1.000000   -4988.940000    2010.000000
# 25%        11.000000      18.000000    2079.650000    2010.000000
# 50%        22.000000      37.000000    7612.030000    2011.000000
# 75%        33.000000      74.000000   20205.852500    2012.000000
# max        45.000000      99.000000  693099.360000    2012.000000
# Minimum "Weekly Sales" is negative.
# \Hoogste omzet is 693099.360000
# <AxesSubplot:xlabel='Weekly_Sales'>

# %% [markdown]
# ## 2 Componenten van een dataframe
# - Print een Numpy array met daarin de eerste 20 rijen van het dataframe.

# %%
display(sales.head(20).to_numpy())
# Out:
# array([[1, 1, Timestamp('2010-02-05 00:00:00'), 24924.5, False, 2010],
#        [1, 1, Timestamp('2010-02-12 00:00:00'), 46039.49, True, 2010],
#        [1, 1, Timestamp('2010-02-19 00:00:00'), 41595.55, False, 2010],
#        [1, 1, Timestamp('2010-02-26 00:00:00'), 19403.54, False, 2010],
#        [1, 1, Timestamp('2010-03-05 00:00:00'), 21827.9, False, 2010],
#        [1, 1, Timestamp('2010-03-12 00:00:00'), 21043.39, False, 2010],
#        [1, 1, Timestamp('2010-03-19 00:00:00'), 22136.64, False, 2010],
#        [1, 1, Timestamp('2010-03-26 00:00:00'), 26229.21, False, 2010],
#        [1, 1, Timestamp('2010-04-02 00:00:00'), 57258.43, False, 2010],
#        [1, 1, Timestamp('2010-04-09 00:00:00'), 42960.91, False, 2010],
#        [1, 1, Timestamp('2010-04-16 00:00:00'), 17596.96, False, 2010],
#        [1, 1, Timestamp('2010-04-23 00:00:00'), 16145.35, False, 2010],
#        [1, 1, Timestamp('2010-04-30 00:00:00'), 16555.11, False, 2010],
#        [1, 1, Timestamp('2010-05-07 00:00:00'), 17413.94, False, 2010],
#        [1, 1, Timestamp('2010-05-14 00:00:00'), 18926.74, False, 2010],
#        [1, 1, Timestamp('2010-05-21 00:00:00'), 14773.04, False, 2010],
#        [1, 1, Timestamp('2010-05-28 00:00:00'), 15580.43, False, 2010],
#        [1, 1, Timestamp('2010-06-04 00:00:00'), 17558.09, False, 2010],
#        [1, 1, Timestamp('2010-06-11 00:00:00'), 16637.62, False, 2010],
#        [1, 1, Timestamp('2010-06-18 00:00:00'), 16216.27, False, 2010]],
#       dtype=object)

# %% [markdown]
# - Print de kolomnamen van sales.

# %%
display(sales.columns)
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object')

# %% [markdown]
# - Print de index van sales.

# %%
display(sales.index)
# Out:
# RangeIndex(start=0, stop=421570, step=1)

# %% [markdown]
# ## 3 Sorteren
# - Sorteer sales op datum in oplopende volgorde en sla dit op als het dataframe sales_date.
# - print de eerste 10 rijen van sales_date.

# %%
sales_date = sales.sort_values('Date', ascending=True)

display(sales_date.head(10))
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Year
# 0           1     1 2010-02-05      24924.50      False  2010
# 277665     29     5 2010-02-05      15552.08      False  2010
# 277808     29     6 2010-02-05       3200.22      False  2010
# 277951     29     7 2010-02-05      10820.05      False  2010
# 278094     29     8 2010-02-05      20055.64      False  2010
# 16451       2    49 2010-02-05      15767.00      False  2010
# 278237     29     9 2010-02-05       4419.73      False  2010
# 278380     29    10 2010-02-05       7550.67      False  2010
# 278523     29    11 2010-02-05       6964.21      False  2010
# 278666     29    12 2010-02-05       2293.66      False  2010

# %% [markdown]
# ## 4 Selecteren van kolommen
# - Maak een nieuw dataframe sales_holiday waarin alleen deze kolommen staan: Date en IsHoliday.
# - Toon de eerste 5 rijen.

# %%
sales_holiday = sales[['Date', 'IsHoliday']] 

display(sales_holiday.head(5))
# Out:
#         Date  IsHoliday
# 0 2010-02-05      False
# 1 2010-02-12       True
# 2 2010-02-19      False
# 3 2010-02-26      False
# 4 2010-03-05      False

# %% [markdown]
# ## 5 Selecteren op datum
# - Toon een nieuw dataframe sales_holiday_2011 dat alleen regels uit 2011 bevat.

# %%
sales_holiday_2011 = sales_holiday[sales_holiday['Date'].dt.year==2011]
display(sales_holiday_2011)
# Out:
#              Date  IsHoliday
# 48     2011-01-07      False
# 49     2011-01-14      False
# 50     2011-01-21      False
# 51     2011-01-28      False
# 52     2011-02-04      False
# ...           ...        ...
# 421522 2011-12-02      False
# 421523 2011-12-09      False
# 421524 2011-12-16      False
# 421525 2011-12-23      False
# 421526 2011-12-30       True
#
# [153453 rows x 2 columns]

# %% [markdown]
# ## 6 Selecteren op meerdere criteria
# - Toon een nieuw dataframe holiday_2011_q4 waarin alleen de verkopen van het vierde kwartaal van 2011 staan die plaats vonden tijdens een vakantie (IsHoliday)

# %%
holiday_2011_q4 = sales[(sales['Date'].dt.quarter==4) & (sales['IsHoliday'] == True ) & (sales['Date'].dt.year==2011) ]
display(holiday_2011_q4)
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Year
# 94          1     1 2011-11-25      20911.25       True  2011
# 99          1     1 2011-12-30      23350.88       True  2011
# 237         1     2 2011-11-25      44259.59       True  2011
# 242         1     2 2011-12-30      43539.94       True  2011
# 380         1     3 2011-11-25       9317.56       True  2011
# ...       ...   ...        ...           ...        ...   ...
# 421246     45    95 2011-12-30      42084.36       True  2011
# 421386     45    97 2011-11-25       5200.55       True  2011
# 421391     45    97 2011-12-30       5569.82       True  2011
# 421521     45    98 2011-11-25        794.62       True  2011
# 421526     45    98 2011-12-30        553.21       True  2011
#
# [6024 rows x 6 columns]

# %% [markdown]
# ## 7 Selecteren met categoriale variabelen.
# - Maak de list st1_5 met daarin de getallen 1 tot en met 5.
# - Toon een nieuw dataframe sales_1_5 waarin alleen de rijen uit sales van de winkels (Store) 1 tot en met 5 worden getoond. Gebruik hierbij st1_5.

# %%
st1_5 = list(range(1,6))
sales_1_5 = sales[sales['Store'].isin(st1_5)]
display (sales_1_5)
# Out:
#        Store  Dept       Date  Weekly_Sales  IsHoliday
# 0          1     1 2010-02-05      24924.50      False
# 1          1     1 2010-02-12      46039.49       True
# 2          1     1 2010-02-19      41595.55      False
# 3          1     1 2010-02-26      19403.54      False
# 4          1     1 2010-03-05      21827.90      False
# ...      ...   ...        ...           ...        ...
# 48784      5    98 2012-07-06         94.50      False
# 48785      5    98 2012-07-13         27.00      False
# 48786      5    98 2012-07-20          8.00      False
# 48787      5    98 2012-08-03         10.00      False
# 48788      5    98 2012-08-10         22.00      False
#
# [48789 rows x 5 columns]

# %% [markdown]
# ## 8 Nieuwe kolom maken
# - De dataframe method .dt kan worden gebruikt om het jaar van een datum te bepalen. Zoek op het internet om uit te vinden hoe dit werkt.
# - Maak de nieuwe kolom 'Year' in sales waarin het jaar wordt getoond.

# %%
sales['Year'] = sales['Date'].dt.year

display(sales)
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Year
# 0           1     1 2010-02-05      24924.50      False  2010
# 1           1     1 2010-02-12      46039.49       True  2010
# 2           1     1 2010-02-19      41595.55      False  2010
# 3           1     1 2010-02-26      19403.54      False  2010
# 4           1     1 2010-03-05      21827.90      False  2010
# ...       ...   ...        ...           ...        ...   ...
# 421565     45    98 2012-09-28        508.37      False  2012
# 421566     45    98 2012-10-05        628.10      False  2012
# 421567     45    98 2012-10-12       1061.02      False  2012
# 421568     45    98 2012-10-19        760.01      False  2012
# 421569     45    98 2012-10-26       1076.80      False  2012
#
# [421570 rows x 6 columns]

# %% [markdown]
# ## 9 Integratie.
# - Maak het nieuwe dataframe sales_75. Dit dataframe bevat alleen de rijen die voldoen aan de volgende voorwaarden:
#     - De omzet (Weekly_Sales) zit in het 75e percentiel.
#     - De verkopen vonden plaats tijdens een vakantieweek (IsHoliday) in 2010.
# - Sorteer de rijen op omzet (Weekly_Sales) in aflopende volgorde.

# %%
sales_75 = sales[(sales['Weekly_Sales'].ge(sales['Weekly_Sales'].quantile(q=0.75))) & (sales['IsHoliday'] == True) & (sales_holiday['Date'].dt.year==2011)].sort_values('Weekly_Sales', ascending=False)
print (sales_75)
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Year
# 338013     35    72 2011-11-25     649770.18       True  2011
# 95425      10    72 2011-11-25     630999.19       True  2011
# 195140     20    72 2011-11-25     392023.02       True  2011
# 37253       4    72 2011-11-25     385051.04       True  2011
# 135717     14    72 2011-11-25     375948.31       True  2011
# ...       ...   ...        ...           ...        ...   ...
# 129461     14    10 2011-11-25      20248.93       True  2011
# 191928     20    34 2011-11-25      20236.21       True  2011
# 238467     25    10 2011-09-09      20234.84       True  2011
# 284268     29    72 2011-09-09      20230.62       True  2011
# 1513        1    11 2011-09-09      20208.40       True  2011
#
# [3168 rows x 6 columns]
